# %% [markdown]
# ## Change point analysis

# %% [markdown]
# - Change Point Analysis
# - Estimate Change Point using Baysian Model
# - Analyze the impact of Events on oil price

# %%
 # Import require libraries and modules
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
# Add the 'scripts' directory to the Python path for module imports
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# Set max rows and columns to display
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# Configure logging
from logger import SetupLogger
# Assuming this class is defined in scripts/
from change_point_analysis import ChangePointAnalyzer


logger = SetupLogger(log_file='../logs/change_point_analysis.log').get_logger()
# Set default figure size for all plots
plt.rcParams['figure.figsize'] = (14, 7)

# %%
# Load data into a pandas DataFrame
price_data = pd.read_csv('../data/BrentOilPrices.csv')
price_data['Date'] = pd.to_datetime(price_data['Date'], format='mixed')
price_data.set_index('Date', inplace=True)

# %%
# Usage example
analyzer = ChangePointAnalyzer(price_data, logger=logger)
# Calculate CUSUM
analyzer.calculate_cusum()

# %% [markdown]
# **Change Point Analysis with ruptures**

# %%
analyzer.detect_change_point()
# Out:
# Detected change point years: [Timestamp('1999-11-09 00:00:00'), Timestamp('2004-07-27 00:00:00'), Timestamp('2010-11-30 00:00:00'), Timestamp('2014-12-02 00:00:00'), Timestamp('2021-09-22 00:00:00')]

# %% [markdown]
# **Change Point Analysis using baysian model**

# %%
change_point_date = analyzer.bayesian_change_point_detection()
# Out:
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(9010)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpvqd7cp92\m41bb13d351c72a658fe4692888dde8094bb44ba85b102f37708e39d91e5dae9e.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpvqd7cp92\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpvqd7cp92\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_ti4jf6ps
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(0)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp2txc_ku4\maf2ab44f36a115d942eaa409f38d2f739449a0eb27bd3743a592f854a7f7cc79.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp2txc_ku4\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp2txc_ku4\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_e17lh6r8
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(9010)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpjeb82w_7\m41bb13d351c72a658fe4692888dde8094bb44ba85b102f37708e39d91e5dae9e.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpjeb82w_7\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpjeb82w_7\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_0niszv07
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(0)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpa_4fadjb\maf2ab44f36a115d942eaa409f38d2f739449a0eb27bd3743a592f854a7f7cc79.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpa_4fadjb\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpa_4fadjb\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_0q0hhugp
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(9010)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp9ifmmw8h\m41bb13d351c72a658fe4692888dde8094bb44ba85b102f37708e39d91e5dae9e.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp9ifmmw8h\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp9ifmmw8h\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_24zoh7vn
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(0)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpb_auqza5\maf2ab44f36a115d942eaa409f38d2f739449a0eb27bd3743a592f854a7f7cc79.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpb_auqza5\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpb_auqza5\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_ua8j4ool
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(0)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpbqm3y8tz\maf2ab44f36a115d942eaa409f38d2f739449a0eb27bd3743a592f854a7f7cc79.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpbqm3y8tz\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpbqm3y8tz\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_8cdvkoze
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(9010)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpdrz6eb1x\m41bb13d351c72a658fe4692888dde8094bb44ba85b102f37708e39d91e5dae9e.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpdrz6eb1x\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpdrz6eb1x\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# ...
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpki6amygn\maf2ab44f36a115d942eaa409f38d2f739449a0eb27bd3743a592f854a7f7cc79.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpki6amygn\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpki6amygn\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_67sr3b8c
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Floor(9010)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpqru6trrh\m41bb13d351c72a658fe4692888dde8094bb44ba85b102f37708e39d91e5dae9e.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpqru6trrh\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmpqru6trrh\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_ob82nz17
# library ine>: is not found.
# library ine is not found.
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: Cast{float64}(5)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1916, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\graph\rewriting\basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\tensor\rewriting\basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1186, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#                                                              ^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1103, in __compile__
#     thunk, module = self.cthunk_factory(
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1631, in cthunk_factory
#     module = cache.module_from_key(key=key, lnk=self)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\basic.py", line 1532, in compile_cmodule
#     module = c_compiler.compile_str(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# "C:\msys64\ucrt64\bin\g++.EXE" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=skylake -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512vbmi -mno-avx512ifma -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mclflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mxsavec -mxsaveopt -mxsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni -mno-avx512fp16 -mno-avxifma -mno-avxvnniint8 -mno-avxneconvert -mno-cmpccxadd -mno-amx-fp16 -mno-prefetchi -mno-raoint -mno-amx-complex -mno-avxvnniint16 -mno-sm3 -mno-sha512 -mno-sm4 -mno-apxf -mno-usermsr --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=8192 -mtune=skylake -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\numpy\core\include" -I"c:\Users\Tsegaye\anaconda3\include" -I"c:\Users\Tsegaye\anaconda3\Lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\Tsegaye\anaconda3\libs" -L"c:\Users\Tsegaye\anaconda3" -o "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp2hxa2ypz\m0de214ec04e404e0b98e77bebd2d95875e2e4b7b75c150c7f6478c42e61da0fa.pyd" "C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp2hxa2ypz\mod.cpp" "c:\Users\Tsegaye\anaconda3\python312.dll"
# In file included from c:\Users\Tsegaye\anaconda3\include/Python.h:12,
#                  from C:\Users\Tsegaye\AppData\Local\PyTensor\compiledir_Windows-11-10.0.22621-SP0-Intel64_Family_6_Model_142_Stepping_10_GenuineIntel-3.12.3-64\tmp2hxa2ypz\mod.cpp:1:
# c:\Users\Tsegaye\anaconda3\include/pyconfig.h:240:9: warning: "MS_WIN64" redefined
#   240 | #define MS_WIN64
#       |         ^~~~~~~~
# <command-line>: note: this is the location of the previous definition
# cc1plus.exe: note: unrecognized command-line option '-Wno-c++11-narrowing' may have been intended to silence earlier diagnostics
# collect2.exe: error: ld returned 116 exit status
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_igdj7v5n
# library ine>: is not found.
# library ine is not found.
#
# You can find the C code in this temporary file: C:\Users\Tsegaye\AppData\Local\Temp\pytensor_compilation_error_7xly32hm
# library ine>: is not found.
# library ine is not found.
